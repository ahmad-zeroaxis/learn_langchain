# %% [markdown]
# ## Character based splitting

# %%
from langchain_text_splitters import CharacterTextSplitter

# %%
text = """
C++ is a general-purpose programming language that was developed by Bjarne Stroustrup in the 1980s. It is an extension of the C programming language and is designed to be more efficient, powerful, and easier to use. C++ is used for developing a wide range of applications, including operating systems, games, and scientific simulations.
"""

# %%
splitter = CharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=0,
    separator=''
)

# %%
# returns a list of strings with chunks
chunks = result = splitter.split_text(text)

# %%
for index, chunk in enumerate(chunks):
    print(f"\n---- Chunk {index+1} ----")
    print(chunk)
# Out:
# C++ is a general-purpose programming language that was developed by Bjarne Stroustrup in the 1980s.
# the 1980s. It is an extension of the C programming language and is designed to be more efficient, po
# icient, powerful, and easier to use. C++ is used for developing a wide range of applications, includ
# ns, including operating systems, games, and scientific simulations.
